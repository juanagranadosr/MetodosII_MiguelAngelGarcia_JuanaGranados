# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib as mpl
import matplotlib.animation as animation
from tqdm import tqdm

# %%
Nt = 11
Nx = 6
Ny = 6

x = np.linspace(0,1,Nx)
y = np.linspace(0,1,Nx)
t = np.linspace(0,1,Nt)

deltax = x[1] - x[0]
deltay = y[1] - y[0]
deltat = t[1] - t[0]

k = 1

lambda_ = (k*deltat)/deltax**2
mu_ = (k*deltat)/deltay**2

print(lambda_,mu_)
# Out:
# 49.25125628140703 49.25125628140703

# %%
def Ti(x,y):
    return np.sin(np.pi*(x+y))

# %%
def InitT():
    
    T = np.zeros((Nt,Nx,Ny))
    
    T[0,:,:] = Ti(x,y)
    # T[:,:,0] = 10.
    # T[:,-1,:] = 5.
    
    return T

# %%
def condiciones_frontera_1(t):
    return np.e**(-2*np.pi**2*t)*np.sin(np.pi*y)

# %%
def condiciones_frontera_2(t):
    return np.e**(-2*np.pi**2*t)*np.sin(np.pi*x)

# %%
def condiciones_frontera_3(t):
    return np.e**(-2*np.pi**2*t)*np.sin(np.pi*(1+y))

# %%
def condiciones_frontera_4(t):
    return np.e**(-2*np.pi**2*t)*np.sin(np.pi*(1+x))

# %%
T = InitT()
#print(T[0,:,:])

# %%
def GetSolution():
    
    for l in tqdm(range(1,len(t))):
        
        #T[l,0,:] = np.sin(20*t[l])
        
        # CONDICIONES DE FRONTERA
        T[l,0,:] = condiciones_frontera_1(l)
        T[l,:,0] = condiciones_frontera_2(l)
        
        T[l,-1,:] = condiciones_frontera_3(l)
        T[l,:,-1] = condiciones_frontera_4(l)
        
        for i in range(1,len(x)-1):
            for j in range(1,len(y)-1):
                T[l,i,j] = (1-2*lambda_-2*mu_)*T[l-1,i,j] + \
                lambda_*(T[l-1,i+1,j] + T[l-1,i-1,j]) + \
                mu_*(T[l-1,i,j+1] + T[l-1,i,j-1])

# %%
GetSolution()
# Out:
#  60%|████████████████████████▌                | 119/199 [00:01<00:00, 97.71it/s]/var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_86828/3267995104.py:16: RuntimeWarning: overflow encountered in double_scalars
#   T[l,i,j] = (1-2*lambda_-2*mu_)*T[l-1,i,j] + \
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_86828/3267995104.py:17: RuntimeWarning: overflow encountered in double_scalars
#   lambda_*(T[l-1,i+1,j] + T[l-1,i-1,j]) + \
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_86828/3267995104.py:18: RuntimeWarning: overflow encountered in double_scalars
#   mu_*(T[l-1,i,j+1] + T[l-1,i,j-1])
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_86828/3267995104.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   mu_*(T[l-1,i,j+1] + T[l-1,i,j-1])
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_86828/3267995104.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   lambda_*(T[l-1,i+1,j] + T[l-1,i-1,j]) + \
# /var/folders/qn/vxgw72n52zv0lbnxjfvcc8zr0000gn/T/ipykernel_86828/3267995104.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   T[l,i,j] = (1-2*lambda_-2*mu_)*T[l-1,i,j] + \
# 100%|█████████████████████████████████████████| 199/199 [00:02<00:00, 96.87it/s]

# %%
fig = plt.figure(figsize=(5,6))
ax = fig.add_subplot(111, projection='3d')

X,Y = np.meshgrid(x,y)

def init():
    
    
    ax.set_xlim3d(0,1.5)
    ax.set_ylim3d(0,1.5)
    ax.set_zlim3d(0,1.5)

def Update(i):

    ax.clear()
    init()
    
    ax.plot_surface(X,Y,T[i,:,:],cmap='viridis')
    
Animation = animation.FuncAnimation(fig,Update,frames=len(t),init_func=init)
# Out:
# <img src="data:image/png;base64,..." width="500">
