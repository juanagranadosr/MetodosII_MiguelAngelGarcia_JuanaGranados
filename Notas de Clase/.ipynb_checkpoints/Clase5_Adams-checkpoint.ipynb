# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate

# %%
def f(x,y):
    return x + 2*y

# %%
def Solucion(x):
    return -0.5*x - (1-np.exp(2*x))/4.

# %%
N = 10
t = np.linspace(0,1,N)

# %%
h = t[1] - t[0]

# %%
yext = Solucion(t)

# %%
plt.scatter(t,yext)

# %%
def GetEuler(f, x, y0):
    h = x[1]-x[0]
    y = np.zeros_like(x)
    y[0] = y0
    
    for i in range(1,len(x)):
        k1 = f(x[i-1], y[i-1])
        y[i] = y[i-1]+h*k1
        
    return y

# %%
yrk1 = GetEuler(f,t,0)

# %%
plt.plot(t,yext)
plt.plot(t,yrk1)

# %%
def GetAdams(f, x, yrk1):
    h = x[1] - x[0]
    y = yrk1.copy()
    
    for i in range(2, len(x)):
        y[i] = y[i-1] + 0.5*h*(3*f(x[i-1], y[i-1]) - f(x[i-2], y[i-2])) 
        # es un indice menor que en las notas
    return y

# %%
ybash2 = GetAdams(f,t,yrk1)
plt.plot(t,yext)
plt.plot(t,yrk1)
plt.plot(t,ybash2,label='Adams')
plt.legend()

# %%
def GetAdamsMoulton(f,x,yrk1):
    h = x[1] - x[0] # paso de integración
    y = yrk1.copy() # hago copia de euler ya que uso el paso "pasado"
    
    yc = y.copy()
    
    for i in range(2, len(x)):
        y[i] = y[i-1] + 0.5*h*(3*f(x[i-1], y[i-1]) - f(x[i-2], y[i-2])) 
        # es un indice menor que en las notas, estan corridos
        
        yc[i] = y[i]
        
        # Moulton ord 2
        #yc[i] = yc[i-1] + 0.5*h*(f(x[i], y[i]) + f(x[i-1], y[i-1]))
        
        # Moulton ord 5
        yc[i] = yc[i-1] + h*(5*f(x[i], y[i]) + 8*f(x[i-1], y[i-1]) - f(x[i-2], y[i-2]))/12
        
    return y, yc

# %%
ybash2, ymulton2 = GetAdamsMoulton(f,t,yrk1)
plt.plot(t,yext, label = 'og')
plt.plot(t,yrk1, label = 'Euler 1')
plt.plot(t,ybash2, label='Adams')
plt.plot(t,ymulton2, label='Adams-Multon')
plt.legend()
